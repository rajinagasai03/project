# %%
# displaying records in the data set
pd.set_option('display.max_columns',None)
boDf=pd.read_csv('c:\cc\ebd.csv')
boDf
# Out:
#                            NAME                 DEPARTMENT_NAME  \
# 0                Gavin,Donna M.        Boston Police Department
# 1             Cassellius,Brenda                  Superintendent
# 2                  Dempsey,John          Boston Fire Department
# 3              Demesmin,Stanley        Boston Police Department
# 4                  Smith,Sean P        Boston Police Department
# ...                         ...                             ...
# 23199  wheeler,Stephen clifford  Boston Cntr - Youth & Families
# 23200             Harris,Gloria       BPS Office Of Budget Mgmt
# 23201       Jackson,Wanita Tina        Boston Police Department
# 23202              Paul,Desmond    BPS Substitute Teachers/Nurs
# 23203         Robinson,Marvin L    BPS Substitute Teachers/Nurs
#
#                          TITLE     REGULAR RETRO         OTHER    OVERTIME  \
# 0      Police Lieutenant (Det)   53,226.90   NaN  1,045,845.44      463.52
# ...

# %%
# number of rows and columns
boDf.shape
# Out:
# (23204, 12)

# %%
# general info
boDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23204 entries, 0 to 23203
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   NAME             23204 non-null  object
#  1   DEPARTMENT_NAME  23204 non-null  object
#  2   TITLE            23204 non-null  object
#  3   REGULAR          22604 non-null  object
#  4   RETRO            3092 non-null   object
#  5   OTHER            15826 non-null  object
#  6   OVERTIME         6812 non-null   object
#  7   INJURED          1221 non-null   object
#  8   DETAIL           2116 non-null   object
#  9   QUINN_EDUCATION  1369 non-null   object
#  10  TOTAL_ GROSS     23204 non-null  object
#  11  POSTAL           23204 non-null  object
# dtypes: object(12)
# memory usage: 2.1+ MB

# %%
#top 5 
bodf.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15324\2502501106.py in <module>
#       1 #top 5
# ----> 2 bodf.head()
#
# NameError: name 'bodf' is not defined

# %%
#wanted no of rows 
boDf.head(15)
# Out:
#                   NAME           DEPARTMENT_NAME  \
# 0       Gavin,Donna M.  Boston Police Department
# 1    Cassellius,Brenda            Superintendent
# 2         Dempsey,John    Boston Fire Department
# 3     Demesmin,Stanley  Boston Police Department
# 4         Smith,Sean P  Boston Police Department
# 5   McCormick,Kelley J  Boston Police Department
# 6       Long,Gregory P  Boston Police Department
# 7     Danilecki,John H  Boston Police Department
# 8         Webb,Keith A  Boston Police Department
# 9     McMahon,Joseph G    Boston Fire Department
# 10  Doherty,Michael J.    Boston Fire Department
# 11      Sweeney,Steven  Boston Police Department
# 12     Cahill,Gerard M    Boston Fire Department
# 13   Hocking,Michael E    Boston Fire Department
# 14   Barrett,Thomas E.  Boston Police Department
#
#                             TITLE     REGULAR RETRO         OTHER    OVERTIME  \
# 0         Police Lieutenant (Det)   53,226.90   NaN  1,045,845.44      463.52
# ...

# %%
#extract all the columns of dataset
boDf.columns
# Out:
# Index(['NAME', 'DEPARTMENT_NAME', 'TITLE', 'REGULAR', 'RETRO', 'OTHER',
#        'OVERTIME', 'INJURED', 'DETAIL', 'QUINN_EDUCATION', 'TOTAL_ GROSS',
#        'POSTAL'],
#       dtype='object')

# %%
# check for null values 
boDf.isna().sum()
# Out:
# NAME                   0
# DEPARTMENT_NAME        0
# TITLE                  0
# REGULAR              600
# RETRO              20112
# OTHER               7378
# OVERTIME           16392
# INJURED            21983
# DETAIL             21088
# QUINN_EDUCATION    21835
# TOTAL_ GROSS           0
# POSTAL                 0
# dtype: int64

# %%
#check duplicate values 
boDf.duplicated().sum()
# Out:
# 0

# %%
#calculate the mean, std and other stastic attributes
boDf.describe()
# Out:
#                  NAME           DEPARTMENT_NAME    TITLE     REGULAR   RETRO  \
# count           23204                     23204    23204       22604    3092
# unique          23133                       232     1507       19422    2917
# top     Kelly,Michael  Boston Police Department  Teacher  104,644.14  728.97
# freq                4                      3040     5304          49      25
#
#            OTHER OVERTIME    INJURED  DETAIL QUINN_EDUCATION TOTAL_ GROSS  \
# count      15826     6812       1221    2116            1369        23204
# unique      6294     6740       1150    1246             818        22428
# top     1,250.00   283.12  94,596.32  368.00       26,161.00     1,500.00
# freq        1149        4          9      77              31           31
#
#        POSTAL
# count   23204
# unique    580
# top     02124
# freq     1867

# %%
#show unique values 
for i, col in enumerate(boDf.columns):
    print(f"\n\n{boDf[col].unique()}")
    print(f"\n{boDf[col].value_counts()}\n\n")
# Out:
# ['Gavin,Donna M.' 'Cassellius,Brenda' 'Dempsey,John' ...
#  'Jackson,Wanita Tina' 'Paul,Desmond' 'Robinson,Marvin L']
#
# Kelly,Michael            4
# Kelly,Michael Joseph     3
# Sullivan,Michael         3
# Sullivan,Kevin           2
# Sanchez,David            2
#                         ..
# Roberts,Eleanor          1
# Knight,Sacha McIntosh    1
# Conille,Pharamond        1
# Jette,Drina              1
# Robinson,Marvin L        1
# Name: NAME, Length: 23133, dtype: int64
#
#
#
#
# ['Boston Police Department' 'Superintendent' 'Boston Fire Department'
#  'Inspectional Services Dept' 'BPS Human Resource Team'
#  'Public Works Department' 'School Support & Tranformation'
#  'Strategy Department' 'Boston Public Library'
#  'Workers Compensation Service' 'Kennedy, EM Health Academy'
#  'BPS Facility Management' 'Election Division' "Mayor's Office"
#  'Dpt of Innovation & Technology' 'Traffic Division' 'Eliot K-8'
#  'BPS Facility Mgmt/A & R' 'BPS Special Education'
# ...

# %%
import pandas as pd
pd.set_option('display.max_columns',None)
boDf=pd.read_csv('c:\cc\ebd.csv')
boDf
# Out:
#                            NAME                 DEPARTMENT_NAME  \
# 0                Gavin,Donna M.        Boston Police Department
# 1             Cassellius,Brenda                  Superintendent
# 2                  Dempsey,John          Boston Fire Department
# 3              Demesmin,Stanley        Boston Police Department
# 4                  Smith,Sean P        Boston Police Department
# ...                         ...                             ...
# 23199  wheeler,Stephen clifford  Boston Cntr - Youth & Families
# 23200             Harris,Gloria       BPS Office Of Budget Mgmt
# 23201       Jackson,Wanita Tina        Boston Police Department
# 23202              Paul,Desmond    BPS Substitute Teachers/Nurs
# 23203         Robinson,Marvin L    BPS Substitute Teachers/Nurs
#
#                          TITLE     REGULAR RETRO         OTHER    OVERTIME  \
# 0      Police Lieutenant (Det)   53,226.90   NaN  1,045,845.44      463.52
# ...

# %%
#check the skewness of the attributes
import numpy as np
intFloatboDf=boDf.select_dtypes([np.int,np.float])
for i, col in enumerate(intFloatboDf.columns):
    if (intFloatboDf[col].skew()>= 0.1):
        print("\n",col,"feature is positively skewed and value is:", intFloatboDf[col].skew()) 
    elif (intFloatboDf[col].skew()<= -0.1):
        print("\n",col,"feature is negtively skewed and value is:", intFloatboDf[col].skew())
    else:
        print("\n",col,"feature is normally distributed and value is:", intFloatboDf[col].skew())
# Out:
# C:\Users\omita\AppData\Local\Temp\ipykernel_15324\1719214276.py:3: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   intFloatboDf=boDf.select_dtypes([np.int,np.float])
# C:\Users\omita\AppData\Local\Temp\ipykernel_15324\1719214276.py:3: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# ...

# %%
boDf.tail()
# Out:
#                            NAME                 DEPARTMENT_NAME  \
# 23199  wheeler,Stephen clifford  Boston Cntr - Youth & Families
# 23200             Harris,Gloria       BPS Office Of Budget Mgmt
# 23201       Jackson,Wanita Tina        Boston Police Department
# 23202              Paul,Desmond    BPS Substitute Teachers/Nurs
# 23203         Robinson,Marvin L    BPS Substitute Teachers/Nurs
#
#                        TITLE REGULAR RETRO OTHER OVERTIME INJURED DETAIL  \
# 23199            Lifeguard I   42.01   NaN   NaN      NaN     NaN    NaN
# 23200              Attendant   24.23   NaN   NaN      NaN     NaN    NaN
# 23201    School Traffic Supv   23.68   NaN   NaN      NaN     NaN    NaN
# 23202  Substitute Teacher HE   21.28   NaN   NaN      NaN     NaN    NaN
# 23203  Substitute Teacher HE   14.06   NaN   NaN      NaN     NaN    NaN
#
#       QUINN_EDUCATION TOTAL_ GROSS POSTAL
# 23199             NaN        42.01  02129
# 23200             NaN        24.23  02136
# ...

# %%
boDf = bodf.astype({"REGULAR": int},errors='ignore')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15324\3740689329.py in <module>
# ----> 1 boDf = bodf.astype({"REGULAR": int},errors='ignore')
#
# NameError: name 'bodf' is not defined

# %%
boDf.shape
# Out:
# (23204, 12)

# %%
import pandas as pd
import numpy as np


# Load the dataset
df = pd.read_csv('c:\cc\ebd.csv')

# Convert relevant columns to numerical data types
numerical_columns = ['Base Salary', 'Overtime', 'Total Compensation']

# Remove any non-numeric characters (e.g., $, commas) and convert to float
df[numerical_columns] = df[numerical_columns].replace({'\$': '', ',': ''}, regex=True).astype(float)

# Calculate the skewness of each numerical column
skewness_results = df[numerical_columns].skew()

# Output the skewness results
print("Skewness of numerical columns:")
print(skewness_results)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15324\2557034928.py in <module>
#      10
#      11 # Remove any non-numeric characters (e.g., $, commas) and convert to float
# ---> 12 df[numerical_columns] = df[numerical_columns].replace({'\$': '', ',': ''}, regex=True).astype(float)
#      13
#      14 # Calculate the skewness of each numerical column
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3509             if is_iterator(key):
#    3510                 key = list(key)
# -> 3511             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3512
#    3513         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _get_indexer_strict(self, key, axis_name)
# ...

# %%
import pandas as pd
import numpy as np

# Assuming you have already loaded the dataset into a pandas DataFrame called 'payroll_data'

# Convert numeric columns to float type
numeric_columns = ['Base Salary', 'Overtime', 'Total Compensation']
payroll_data[numeric_columns] = payroll_data[numeric_columns].apply(pd.to_numeric, errors='coerce')

# Check the skewness of the data
skewness = payroll_data[numeric_columns].skew()

# Display the skewness values
print("Skewness of the numerical columns:")
print(skewness)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15324\3633995089.py in <module>
#       6 # Convert numeric columns to float type
#       7 numeric_columns = ['Base Salary', 'Overtime', 'Total Compensation']
# ----> 8 payroll_data[numeric_columns] = payroll_data[numeric_columns].apply(pd.to_numeric, errors='coerce')
#       9
#      10 # Check the skewness of the data
#
# NameError: name 'payroll_data' is not defined
