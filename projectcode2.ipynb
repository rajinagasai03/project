# %%
import pandas as pd
pd.set_option('display.max_columns',None)
df=pd.read_csv('c:\cc\plots.csv')
df
# Out:
#         REGULAR  TOTAL_ GROSS
# 0     53,226.90  11,12,348.25
# 1   1,79,109.61   5,96,949.44
# 2   1,33,653.78   4,46,406.31
# 3   1,45,775.26   3,97,258.69
# 4   1,42,535.62   3,86,054.33
# 5   1,47,690.64   3,74,231.57
# 6   2,90,703.31   3,73,128.34
# 7   1,64,100.70   3,62,145.39
# 8   1,30,930.12   3,54,926.81
# 9   1,46,502.16   3,54,560.72
# 10  2,17,551.17   3,49,748.53
# 11  1,63,885.36   3,49,539.41
# 12     1,303.10   3,48,741.06
# 13  2,11,335.49   3,48,081.16
# 14  1,30,930.12   3,43,881.49
# 15  1,06,986.54   3,43,323.85
# 16  1,16,398.17   3,37,264.09
# 17  1,27,626.76   3,37,030.92
# 18  1,64,500.82   3,30,400.98
# 19  1,27,626.76   3,29,863.15
# 20  1,30,930.12   3,28,320.70
# 21  1,45,775.26   3,27,249.93
# 22  1,64,500.82   3,27,114.01
# 23  1,39,492.40   3,26,699.53
# 24  1,29,658.34   3,23,964.22
# 25  1,32,073.96   3,23,695.51
# 26  1,00,057.00   3,23,172.70
# 27  1,39,529.74   3,20,990.86
# 28  1,44,420.46   3,20,789.25
# 29  1,38,939.74   3,18,693.54
# ...

# %%
import pandas as pd



# Columns containing commas and periods that need to be cleaned
columns_to_clean = ['REGULAR', 'TOTAL_ GROSS']

for column in columns_to_clean:
    df[column] = df[column].str.replace(',', '').str.replace('.', '')

# Verify the cleaned data
print(df.head())
# Out:
#     REGULAR TOTAL_ GROSS
# 0   5322690    111234825
# 1  17910961     59694944
# 2  13365378     44640631
# 3  14577526     39725869
# 4  14253562     38605433
# C:\Users\omita\AppData\Local\Temp\ipykernel_28048\3014160374.py:9: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df[column] = df[column].str.replace(',', '').str.replace('.', '')

# %%
df
# Out:
#      REGULAR TOTAL_ GROSS
# 0    5322690    111234825
# 1   17910961     59694944
# 2   13365378     44640631
# 3   14577526     39725869
# 4   14253562     38605433
# 5   14769064     37423157
# 6   29070331     37312834
# 7   16410070     36214539
# 8   13093012     35492681
# 9   14650216     35456072
# 10  21755117     34974853
# 11  16388536     34953941
# 12    130310     34874106
# 13  21133549     34808116
# 14  13093012     34388149
# 15  10698654     34332385
# 16  11639817     33726409
# 17  12762676     33703092
# 18  16450082     33040098
# 19  12762676     32986315
# 20  13093012     32832070
# 21  14577526     32724993
# 22  16450082     32711401
# 23  13949240     32669953
# 24  12965834     32396422
# 25  13207396     32369551
# 26  10005700     32317270
# 27  13952974     32099086
# 28  14442046     32078925
# 29  13893974     31869354
# 30  13979791     31666916
# 31  13658874     31544783
# 32  16054988     31531500
# 33  13102491     31334704
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have the payroll data in a pandas DataFrame named 'payroll_data'
# Convert relevant columns to numeric types
numeric_columns = ['REGULAR', 'TOTAL_ GROSS']
df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric, errors='coerce')

# Extract first 20 rows
df = payroll_data.head(20)

# Create the scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(df['REGULAR'], df['TOTAL_ GROSS'])
plt.xlabel('Regular Earnings')
plt.ylabel('Total Gross Earnings')
plt.title('Scatter Plot of Regular Earnings vs. Total Gross Earnings')
plt.grid(True)
plt.show()
# Out:
# C:\Users\omita\AppData\Local\Temp\ipykernel_28048\2095947109.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric, errors='coerce')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have the payroll data in a pandas DataFrame named 'payroll_data'
# Convert relevant columns to numeric types (if needed)
numeric_columns = ['REGULAR',  'TOTAL_ GROSS']
df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric, errors='coerce')

# Create histograms for the numeric columns
plt.figure(figsize=(12, 8))

# Plotting 'REGULAR' column histogram
plt.subplot(2, 3, 1)
plt.hist(df['REGULAR'], bins=20, edgecolor='black')
plt.xlabel('Regular Earnings')
plt.ylabel('Frequency')
plt.title('Histogram of Regular Earnings')



# Plotting 'TOTAL GROSS' column histogram
plt.subplot(2, 3, 5)
plt.hist(df['TOTAL_ GROSS'], bins=20, edgecolor='black')
plt.xlabel('Total Gross Earnings')
plt.ylabel('Frequency')
plt.title('Histogram of Total Gross Earnings')

# Adjust layout to prevent overlapping
plt.tight_layout()

# Show the histograms
plt.show()
# Out:
# C:\Users\omita\AppData\Local\Temp\ipykernel_28048\227420925.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric, errors='coerce')
# C:\Users\omita\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6607: RuntimeWarning: All-NaN slice encountered
#   xmin = min(xmin, np.nanmin(xi))
# C:\Users\omita\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6608: RuntimeWarning: All-NaN slice encountered
#   xmax = max(xmax, np.nanmax(xi))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_28048\227420925.py in <module>
# ...

# %%
# Out:
#     REGULAR  TOTAL_ GROSS
# 0       NaN           NaN
# 1       NaN           NaN
# 2       NaN           NaN
# 3       NaN           NaN
# 4       NaN           NaN
# 5       NaN           NaN
# 6       NaN           NaN
# 7       NaN           NaN
# 8       NaN           NaN
# 9       NaN           NaN
# 10      NaN           NaN
# 11      NaN           NaN
# 12      NaN           NaN
# 13      NaN           NaN
# 14      NaN           NaN
# 15      NaN           NaN
# 16      NaN           NaN
# 17      NaN           NaN
# 18      NaN           NaN
# 19      NaN           NaN

# %%
import pandas as pd
pd.set_option('display.max_columns',None)
df=pd.read_csv('c:\cc\plots.csv')
df
# Out:
#         REGULAR  TOTAL_ GROSS
# 0     53,226.90  11,12,348.25
# 1   1,79,109.61   5,96,949.44
# 2   1,33,653.78   4,46,406.31
# 3   1,45,775.26   3,97,258.69
# 4   1,42,535.62   3,86,054.33
# 5   1,47,690.64   3,74,231.57
# 6   2,90,703.31   3,73,128.34
# 7   1,64,100.70   3,62,145.39
# 8   1,30,930.12   3,54,926.81
# 9   1,46,502.16   3,54,560.72
# 10  2,17,551.17   3,49,748.53
# 11  1,63,885.36   3,49,539.41
# 12     1,303.10   3,48,741.06
# 13  2,11,335.49   3,48,081.16
# 14  1,30,930.12   3,43,881.49
# 15  1,06,986.54   3,43,323.85
# 16  1,16,398.17   3,37,264.09
# 17  1,27,626.76   3,37,030.92
# 18  1,64,500.82   3,30,400.98
# 19  1,27,626.76   3,29,863.15
# 20  1,30,930.12   3,28,320.70
# 21  1,45,775.26   3,27,249.93
# 22  1,64,500.82   3,27,114.01
# 23  1,39,492.40   3,26,699.53
# 24  1,29,658.34   3,23,964.22
# 25  1,32,073.96   3,23,695.51
# 26  1,00,057.00   3,23,172.70
# 27  1,39,529.74   3,20,990.86
# 28  1,44,420.46   3,20,789.25
# 29  1,38,939.74   3,18,693.54
# ...

# %%
import pandas as pd



# Columns containing commas and periods that need to be cleaned
columns_to_clean = ['REGULAR', 'TOTAL_ GROSS']

for column in columns_to_clean:
    df[column] = df[column].str.replace(',', '').str.replace('.', '')

# Verify the cleaned data
print(df.head())
# Out:
#     REGULAR TOTAL_ GROSS
# 0   5322690    111234825
# 1  17910961     59694944
# 2  13365378     44640631
# 3  14577526     39725869
# 4  14253562     38605433
# C:\Users\omita\AppData\Local\Temp\ipykernel_28048\3014160374.py:9: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df[column] = df[column].str.replace(',', '').str.replace('.', '')

# %%
df
# Out:
#      REGULAR TOTAL_ GROSS
# 0    5322690    111234825
# 1   17910961     59694944
# 2   13365378     44640631
# 3   14577526     39725869
# 4   14253562     38605433
# 5   14769064     37423157
# 6   29070331     37312834
# 7   16410070     36214539
# 8   13093012     35492681
# 9   14650216     35456072
# 10  21755117     34974853
# 11  16388536     34953941
# 12    130310     34874106
# 13  21133549     34808116
# 14  13093012     34388149
# 15  10698654     34332385
# 16  11639817     33726409
# 17  12762676     33703092
# 18  16450082     33040098
# 19  12762676     32986315
# 20  13093012     32832070
# 21  14577526     32724993
# 22  16450082     32711401
# 23  13949240     32669953
# 24  12965834     32396422
# 25  13207396     32369551
# 26  10005700     32317270
# 27  13952974     32099086
# 28  14442046     32078925
# 29  13893974     31869354
# 30  13979791     31666916
# 31  13658874     31544783
# 32  16054988     31531500
# 33  13102491     31334704
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have the payroll data in a pandas DataFrame named 'payroll_data'
# Convert relevant columns to numeric types (if needed)
numeric_columns = ['REGULAR',  'TOTAL_ GROSS']
df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric, errors='coerce')

# Create histograms for the numeric columns
plt.figure(figsize=(12, 8))

# Plotting 'REGULAR' column histogram
plt.subplot(2, 3, 1)
plt.hist(df['REGULAR'], bins=20, edgecolor='black')
plt.xlabel('Regular Earnings')
plt.ylabel('Frequency')
plt.title('Histogram of Regular Earnings')



# Plotting 'TOTAL GROSS' column histogram
plt.subplot(2, 3, 5)
plt.hist(df['TOTAL_ GROSS'], bins=20, edgecolor='black')
plt.xlabel('Total Gross Earnings')
plt.ylabel('Frequency')
plt.title('Histogram of Total Gross Earnings')

# Adjust layout to prevent overlapping
plt.tight_layout()

# Show the histograms
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have the payroll data in a pandas DataFrame named 'payroll_data'
# Convert relevant columns to numeric types (if needed)
numeric_columns = ['REGULAR', 'TOTAL_ GROSS']
df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric, errors='coerce')

# Calculate the sum of earnings for each numeric column
earnings_sum = df[numeric_columns].sum()

# Create a bar graph for the sum of earnings
plt.figure(figsize=(10, 6))
plt.bar(earnings_sum.index, earnings_sum.values)
plt.xlabel('Earnings Categories')
plt.ylabel('Total Earnings')
plt.title('Bar Graph of Total Earnings by Category')
plt.xticks(rotation=45, ha='right')
plt.show()
